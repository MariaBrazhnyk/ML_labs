# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score, mutual_info_score
from sklearn import preprocessing
import seaborn as sns
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('train.csv', sep=',')
df
# Out:
#                  Artist Name                             Track Name  \
# 0                 Bruno Mars  That's What I Like (feat. Gucci Mane)
# 1                     Boston                           Hitch a Ride
# 2              The Raincoats                     No Side to Fall In
# 3                       Deno             Lingo (feat. J.I & Chunkz)
# 4      Red Hot Chili Peppers      Nobody Weird Like Me - Remastered
# ...                      ...                                    ...
# 17991            Green-House                              Find Home
# 17992               Micatone                               All Gone
# 17993        Smash Hit Combo                           Peine perdue
# 17994                Beherit                         Salomon's Gate
# 17995         The Raconteurs                     Broken Boy Soldier
#
#        Popularity  danceability  energy   key  loudness  mode  speechiness  \
# 0            60.0         0.854   0.564   1.0    -4.964     1       0.0485
# 1            54.0         0.382   0.814   3.0    -7.230     1       0.0406
# 2            35.0         0.434   0.614   6.0    -8.334     1       0.0525
# 3            66.0         0.853   0.597  10.0    -6.528     0       0.0555
# 4            53.0         0.167   0.975   2.0    -4.279     1       0.2160
# ...           ...           ...     ...   ...       ...   ...          ...
# 17991        35.0         0.166   0.109   7.0   -17.100     0       0.0413
# 17992        27.0         0.638   0.223  11.0   -10.174     0       0.0329
# 17993        34.0         0.558   0.981   4.0    -4.683     0       0.0712
# 17994        29.0         0.215   0.805   6.0   -12.757     0       0.1340
# 17995        43.0         0.400   0.853   4.0    -5.320     0       0.0591
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.017100               NaN    0.0849   0.8990  134.071
# 1          0.001100          0.004010    0.1010   0.5690  116.454
# 2          0.486000          0.000196    0.3940   0.7870  147.681
# 3          0.021200               NaN    0.1220   0.5690  107.033
# 4          0.000169          0.016100    0.1720   0.0918  199.060
# ...             ...               ...       ...      ...      ...
# 17991      0.993000          0.824000    0.0984   0.1770  171.587
# 17992      0.858000          0.000016    0.0705   0.3350   73.016
# 17993      0.000030          0.000136    0.6660   0.2620  105.000
# 17994      0.001290          0.916000    0.2560   0.3550  131.363
# 17995      0.006040          0.212000    0.3340   0.3770  138.102
#
#        duration_in min/ms  time_signature  Class
# 0                234596.0               4      5
# 1                251733.0               4     10
# 2                109667.0               4      6
# 3                173968.0               4      5
# 4                229960.0               4     10
# ...                   ...             ...    ...
# 17991            193450.0               3      6
# 17992            257067.0               4      2
# 17993            216222.0               4      8
# 17994            219693.0               4      8
# 17995            182227.0               4     10
#
# [17996 rows x 17 columns]

# %%
df.isnull().values.any()
# Out:
# True

# %%
df = df.dropna()

# %%
df.isnull().values.any()
# Out:
# False

# %%
df = df.reset_index(drop=True)
df
# Out:
#                  Artist Name                         Track Name  Popularity  \
# 0                     Boston                       Hitch a Ride        54.0
# 1              The Raincoats                 No Side to Fall In        35.0
# 2      Red Hot Chili Peppers  Nobody Weird Like Me - Remastered        53.0
# 3                The Stooges  Search and Destroy - Iggy Pop Mix        53.0
# 4              Solomon Burke                None Of Us Are Free        48.0
# ...                      ...                                ...         ...
# 11808            Green-House                          Find Home        35.0
# 11809               Micatone                           All Gone        27.0
# 11810        Smash Hit Combo                       Peine perdue        34.0
# 11811                Beherit                     Salomon's Gate        29.0
# 11812         The Raconteurs                 Broken Boy Soldier        43.0
#
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0             0.382   0.814   3.0    -7.230     1       0.0406      0.001100
# 1             0.434   0.614   6.0    -8.334     1       0.0525      0.486000
# 2             0.167   0.975   2.0    -4.279     1       0.2160      0.000169
# 3             0.235   0.977   6.0     0.878     1       0.1070      0.003530
# 4             0.674   0.658   5.0    -9.647     0       0.1040      0.404000
# ...             ...     ...   ...       ...   ...          ...           ...
# 11808         0.166   0.109   7.0   -17.100     0       0.0413      0.993000
# 11809         0.638   0.223  11.0   -10.174     0       0.0329      0.858000
# 11810         0.558   0.981   4.0    -4.683     0       0.0712      0.000030
# 11811         0.215   0.805   6.0   -12.757     0       0.1340      0.001290
# 11812         0.400   0.853   4.0    -5.320     0       0.0591      0.006040
#
#        instrumentalness  liveness  valence    tempo  duration_in min/ms  \
# 0              0.004010    0.1010   0.5690  116.454            251733.0
# 1              0.000196    0.3940   0.7870  147.681            109667.0
# 2              0.016100    0.1720   0.0918  199.060            229960.0
# 3              0.006040    0.1720   0.2410  152.952            208133.0
# 4              0.000001    0.0981   0.6770  143.292            329387.0
# ...                 ...       ...      ...      ...                 ...
# 11808          0.824000    0.0984   0.1770  171.587            193450.0
# 11809          0.000016    0.0705   0.3350   73.016            257067.0
# 11810          0.000136    0.6660   0.2620  105.000            216222.0
# 11811          0.916000    0.2560   0.3550  131.363            219693.0
# 11812          0.212000    0.3340   0.3770  138.102            182227.0
#
#        time_signature  Class
# 0                   4     10
# 1                   4      6
# 2                   4     10
# 3                   4      6
# 4                   4      2
# ...               ...    ...
# 11808               3      6
# 11809               4      2
# 11810               4      8
# 11811               4      8
# 11812               4     10
#
# [11813 rows x 17 columns]

# %%
scaler = preprocessing.MinMaxScaler()

d = scaler.fit_transform(df.drop(['Artist Name', 'Track Name', 'Class'], axis=1))

df1 = pd.DataFrame(d, columns=df.drop(['Artist Name', 'Track Name', 'Class'], axis=1).columns)
df1['Artist Name'] = df['Artist Name']
df1['Track Name'] = df['Track Name']
df1['Class'] = df['Class']
df1
# Out:
#        Popularity  danceability    energy  key  loudness  mode  speechiness  \
# 0        0.546392      0.343500  0.813996  0.2  0.771487   1.0     0.019836
# 1        0.350515      0.399740  0.613992  0.5  0.742101   1.0     0.032877
# 2        0.536082      0.110967  0.974999  0.1  0.850036   1.0     0.212055
# 3        0.536082      0.184512  0.977000  0.5  0.987303   1.0     0.092603
# 4        0.484536      0.659312  0.657993  0.4  0.707152   0.0     0.089315
# ...           ...           ...       ...  ...       ...   ...          ...
# 11808    0.350515      0.109885  0.108982  0.6  0.508771   0.0     0.020603
# 11809    0.268041      0.620376  0.222984  1.0  0.693125   0.0     0.011397
# 11810    0.340206      0.533852  0.981000  0.3  0.839282   0.0     0.053370
# 11811    0.288660      0.162881  0.804996  0.5  0.624371   0.0     0.122192
# 11812    0.432990      0.362968  0.852997  0.3  0.822327   0.0     0.040110
#
#        acousticness  instrumentalness  liveness   valence     tempo  \
# 0          0.001104      4.025104e-03  0.090909  0.572632  0.459689
# 1          0.487952      1.957833e-04  0.389858  0.799314  0.626804
# 2          0.000170      1.616367e-02  0.163351  0.076427  0.901766
# 3          0.003544      6.063259e-03  0.163351  0.231569  0.655013
# 4          0.405622      3.413658e-07  0.087950  0.684933  0.603316
# ...             ...               ...       ...       ...       ...
# 11808      0.996988      8.273091e-01  0.088256  0.165020  0.754740
# 11809      0.861446      1.516066e-05  0.059790  0.329313  0.227225
# 11810      0.000030      1.355423e-04  0.667381  0.253405  0.398391
# 11811      0.001295      9.196786e-01  0.249056  0.350109  0.539476
# 11812      0.006064      2.128506e-01  0.328640  0.372985  0.575541
#
#        duration_in min/ms  time_signature            Artist Name  \
# 0                0.170413            0.75                 Boston
# 1                0.074240            0.75          The Raincoats
# 2                0.155674            0.75  Red Hot Chili Peppers
# 3                0.140898            0.75            The Stooges
# 4                0.222982            0.75          Solomon Burke
# ...                   ...             ...                    ...
# 11808            0.130958            0.50            Green-House
# 11809            0.174024            0.75               Micatone
# 11810            0.146374            0.75        Smash Hit Combo
# 11811            0.148724            0.75                Beherit
# 11812            0.123361            0.75         The Raconteurs
#
#                               Track Name  Class
# 0                           Hitch a Ride     10
# 1                     No Side to Fall In      6
# 2      Nobody Weird Like Me - Remastered     10
# 3      Search and Destroy - Iggy Pop Mix      6
# 4                    None Of Us Are Free      2
# ...                                  ...    ...
# 11808                          Find Home      6
# 11809                           All Gone      2
# 11810                       Peine perdue      8
# 11811                     Salomon's Gate      8
# 11812                 Broken Boy Soldier     10
#
# [11813 rows x 17 columns]

# %%
plt.figure(figsize=(30,5))
df1.drop(['Artist Name', 'Track Name', 'Class'], axis=1).boxplot()
print()

# %%
def outliers(df, column):
    temp = df[column]
    q1 = temp.quantile(0.25)
    q3 = temp.quantile(0.75)
    irq = q3 - q1
    outliers_min = q1 - (1.5 * irq)
    outliers_max = q3 + (1.5 * irq)
    
    df = df[df[column] >= outliers_min]
    df = df[df[column] <= outliers_max]
    return df

# %%
for col in df1.drop(['Artist Name', 'Track Name', 'Class'], axis=1):
    df1 = outliers(df1, col)

# %%
plt.figure(figsize=(30,5))
df1.drop(['Class'], axis=1).boxplot()
print()

# %%
plt.figure(figsize=(20,7))
cor = df.corr()
sns.heatmap(cor, annot = True, cmap='jet')

# %%
df1 = df1.reset_index(drop=True)

# %%
Y = df1['Class']
X = df1[['Popularity', 'danceability', 'energy', 'loudness', 'acousticness', 'duration_in min/ms']]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
kmeans = KMeans(n_clusters=11, random_state=0).fit(X_train)

# %%
predicted = kmeans.predict(X_test)

# %%
predicted
# Out:
# array([ 8,  4,  6,  7,  0,  6,  3,  9,  2,  7, 10,  7,  7,  3,  5,  0,  3,
#        10,  0,  1,  4,  6,  4,  7,  5,  6,  9,  3,  5,  5,  7, 10,  9,  7,
#         3,  0,  5,  0,  4,  2,  8,  6,  1,  0,  0,  9,  7,  6,  8,  5,  9,
#         4,  9,  3,  9,  2,  3,  6,  2,  7,  2,  7,  1,  3,  1,  7,  3,  2,
#         3,  6,  6,  8,  5,  7,  0, 10, 10,  4,  7,  6,  3])

# %%
kmeans.labels_
# Out:
# array([ 0,  5,  1, 10,  5,  0,  7,  6,  8,  7, 10,  7,  5,  4,  2,  9,  1,
#         7,  8,  7,  6,  6,  2,  3,  3,  0,  8,  3,  1,  3,  5,  0,  3,  0,
#         2,  3,  7,  5,  6,  3,  8,  8,  0,  3,  2,  3,  4,  6,  6,  1,  7,
#         4,  6,  1,  6,  0,  9,  1,  3,  4,  6,  3, 10,  4,  7,  3,  3,  5,
#         2,  0,  2,  3,  5,  6,  4,  2,  0,  7,  7,  0,  9,  2,  3,  8,  7,
#         0,  2,  4,  8,  2,  1,  6,  0,  0,  9,  2,  6,  4,  2,  9,  2,  4,
#         7,  4,  9,  8,  4,  7,  7,  5,  5,  3,  7,  7,  0,  3,  6,  6,  2,
#         2,  1,  4,  2,  1,  4,  8,  3,  8,  8,  4,  0,  2,  2,  2,  6,  0,
#         0,  1,  3,  3,  5,  4,  4,  4,  0,  3,  3,  4,  6,  2,  0,  9,  3,
#         3,  3,  1, 10,  1,  6,  3,  5,  2,  6,  0,  5,  1,  3, 10,  5,  3,
#         2,  2,  2,  0,  9,  5,  8,  5,  0,  6,  4,  6,  6,  1,  5,  2,  3,
#         5,  5,  0,  5,  8,  2,  0,  7,  5,  7,  6,  0,  7,  8,  0,  6,  2,
#         7,  6,  4,  1,  7,  0,  9,  5,  3,  4,  4,  3,  0,  3,  5,  2,  3,
#         8,  7,  2,  0,  4,  3,  6,  7,  1,  7,  3,  5,  1,  0,  2,  4,  2,
#         3,  3,  0,  3,  6,  1,  2, 10,  6,  8,  3,  1,  2,  5,  5,  6,  3,
#         2,  9,  4,  9,  9,  3,  7,  4,  0,  5,  1,  7,  5,  8,  4,  1,  3,
#         3,  6,  2,  7,  4,  1, 10,  7,  0,  3,  3,  1,  1,  6,  7,  2,  9,
#         8,  9, 10,  7,  5,  6,  5,  8,  3,  3,  6,  2,  9, 10,  3,  4,  6,
#         3,  1,  0,  6,  2,  3, 10,  7,  9,  3,  3,  8, 10,  4,  6,  2,  3])
